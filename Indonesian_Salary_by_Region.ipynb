# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d linkgish/indonesian-salary-by-region-19972022
# Out:
# indonesian-salary-by-region-19972022.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# !mkdir /content/indonesian-salary-by-region-19972022

with zipfile.ZipFile('indonesian-salary-by-region-19972022.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/indonesian-salary-by-region')
# Out:
# mkdir: cannot create directory ‘/content/indonesian-salary-by-region-19972022’: File exists

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

# %%
import pandas as pd

df = pd.read_csv("/content/indonesian-salary-by-region/Indonesian Salary by Region (1997-2022).csv")

# Tampilkan DataFrame
print(df.head(2))

pd.set_option('display.max_rows', None)

# Tampilkan DataFrame
print(df)
# Out:
#            REGION  SALARY  YEAR
# 0            ACEH  128000  1997
# 1  SUMATERA UTARA  151000  1997
#                    REGION   SALARY  YEAR
# 0                    ACEH   128000  1997
# 1          SUMATERA UTARA   151000  1997
# 2          SUMATERA BARAT   119000  1997
# 3                    RIAU   151500  1997
# 4                   JAMBI   119500  1997
# 5        SUMATERA SELATAN   127500  1997
# 6                BENGKULU   127500  1997
# 7                 LAMPUNG   126000  1997
# 8               KEP. RIAU   235000  1997
# 9             DKI JAKARTA   172500  1997
# 10             JAWA BARAT   172500  1997
# 11            JAWA TENGAH   113000  1997
# 12          DI YOGYAKARTA   106500  1997
# 13             JAWA TIMUR   132500  1997
# 14                   BALI   141500  1997
# 15    NUSA TENGGARA BARAT   108000  1997
# 16    NUSA TENGGARA TIMUR   106000  1997
# 17       KALIMANTAN BARAT   126500  1997
# 18      KALIMANTAN TENGAH   138000  1997
# ...
